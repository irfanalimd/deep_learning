# %% [markdown]
# # Flower Classification (with Image Augmentation)

# %% [markdown]
# # Importing Packages

# %% [markdown]
# Let's start by importing required packages. **os** package is used to read files and directory structure, **numpy** is used to convert python list to numpy array and to perform required matrix operations and **matplotlib.pyplot** is used to plot the graph and display images in our training and validation data.

# %%
import os
import numpy as np
import glob
import shutil

import tensorflow as tf

import matplotlib.pyplot as plt

# %% [markdown]
# Importing the `ImageDataGenerator` from Keras so that we can perform image augmentation.

# %%
#import packages
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Data Loading

# %% [markdown]
# In order to build our image classifier, we can begin by downloading the flowers dataset. We first need to download the archive version of the dataset and after the download we are storing it to "/tmp/" directory.

# %% [markdown]
# After downloading the dataset, we need to extract its contents.

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228813984/228813984 [==============================] - 1s 0us/step

# %% [markdown]
# The dataset we downloaded contains images of 5 types of flowers:
#
# 1. Rose
# 2. Daisy
# 3. Dandelion
# 4. Sunflowers
# 5. Tulips
#
# So, let's create the labels for these 5 classes:

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

# %% [markdown]
# Also, the dataset we have downloaded has following directory structure.
#
# <pre style="font-size: 10.0pt; font-family: Arial; line-height: 2; letter-spacing: 1.0pt;" >
# <b>flower_photos</b>
# |__ <b>daisy</b>
# |__ <b>dandelion</b>
# |__ <b>roses</b>
# |__ <b>sunflowers</b>
# |__ <b>tulips</b>
# </pre>
#
# As you can see there are no folders containing training and validation data. Therefore, we will have to create our own training and validation set. Let's write some code that will do this.
#
#
# The code below creates a `train` and a `val` folder each containing 5 folders (one for each type of flower). It then moves the images from the original folders to these new folders such that 80% of the images go to the training set and 20% of the images go into the validation set. In the end our directory will have the following structure:
#
#
# <pre style="font-size: 10.0pt; font-family: Arial; line-height: 2; letter-spacing: 1.0pt;" >
# <b>flower_photos</b>
# |__ <b>daisy</b>
# |__ <b>dandelion</b>
# |__ <b>roses</b>
# |__ <b>sunflowers</b>
# |__ <b>tulips</b>
# |__ <b>train</b>
#     |______ <b>daisy</b>: [1.jpg, 2.jpg, 3.jpg ....]
#     |______ <b>dandelion</b>: [1.jpg, 2.jpg, 3.jpg ....]
#     |______ <b>roses</b>: [1.jpg, 2.jpg, 3.jpg ....]
#     |______ <b>sunflowers</b>: [1.jpg, 2.jpg, 3.jpg ....]
#     |______ <b>tulips</b>: [1.jpg, 2.jpg, 3.jpg ....]
#  |__ <b>val</b>
#     |______ <b>daisy</b>: [507.jpg, 508.jpg, 509.jpg ....]
#     |______ <b>dandelion</b>: [719.jpg, 720.jpg, 721.jpg ....]
#     |______ <b>roses</b>: [514.jpg, 515.jpg, 516.jpg ....]
#     |______ <b>sunflowers</b>: [560.jpg, 561.jpg, 562.jpg .....]
#     |______ <b>tulips</b>: [640.jpg, 641.jpg, 642.jpg ....]
# </pre>
#
# Since we don't delete the original folders, they will still be in our `flower_photos` directory, but they will be empty. The code below also prints the total number of flower images we have for each type of flower.

# %%
test = 0
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  if test==0:
    print(img_path,images[:5])
  test+=1
  print("{}: {} Images".format(cl, len(images)))
  train, val = images[:round(len(images)*0.8)], images[round(len(images)*0.8):]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# /root/.keras/datasets/flower_photos/roses ['/root/.keras/datasets/flower_photos/roses/4558025386_2c47314528.jpg', '/root/.keras/datasets/flower_photos/roses/15537825851_a80b6321d7_n.jpg', '/root/.keras/datasets/flower_photos/roses/4918137796_21f0922b0c_n.jpg', '/root/.keras/datasets/flower_photos/roses/5073473370_bdbb5a99fc.jpg', '/root/.keras/datasets/flower_photos/roses/4495885281_fe2a3b671d.jpg']
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %% [markdown]
# For convenience, let us set up the path for the training and validation sets

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %%
total_train = len(os.listdir(train_dir))
print(os.listdir(train_dir))
num_train_examples = len(glob.glob(train_dir + "/*/*"))
num_val_examples = len(glob.glob(val_dir + "/*/*"))
print("Number of training images : {} \nNumber of Validation Images : {}".format(num_train_examples, num_val_examples))
print("Total number of images : {}".format(num_train_examples+num_val_examples))
# Out:
# ['sunflowers', 'dandelion', 'roses', 'tulips', 'daisy']
# Number of training images : 2935
# Number of Validation Images : 735
# Total number of images : 3670

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# Overfitting generally occurs when we have small number of training examples. One way to fix this problem is to augment our dataset so that it has sufficient number of training examples. Data augmentation takes the approach of generating more training data from existing training samples, by augmenting the samples via a number of random transformations that yield believable-looking images. The goal is that at training time, your model will never see the exact same picture twice. This helps expose the model to more aspects of the data and generalize better.
#
# In **tf.keras** we can implement this using the same **ImageDataGenerator** class we used before. We can simply pass different transformations we would want to our dataset as a form of arguments and it will take care of applying it to the dataset during our training process.

# %% [markdown]
#  Before we begin making transformations let's define our `batch_size` and our image size. Remember that the input to our CNN are images of the same size. We therefore have to resize the images in our dataset to the same size.
#
# ## Set Batch and Image Size
#
# In the cell below, we will create a `batch_size` of 100 images and set a value to `IMG_SHAPE` such that our training data consists of images with width of 150 pixels and height of 150 pixels.

# %%
batch_size = 100
IMG_SHAPE = 150

# %% [markdown]
# ### Apply Random Horizontal Flip
#
# In the cell below, We use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random horizontal flip. Then we use the `.flow_from_directory` method to apply the above transformation to the images in our training set. We will make sure that we indicate the batch size, the path to the directory of the training images, the target size for the images, and shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale = 1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(batch_size = batch_size, directory = train_dir, shuffle=True, target_size = (IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %% [markdown]
# Let's take 1 sample image from our training examples and repeat it 5 times so that the augmentation can be applied to the same image 5 times over randomly, to see the augmentation in action.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Apply Random Rotation
#
# In the cell below, we use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random 45 degree rotation. Then we use the `.flow_from_directory` method to apply the above transformation to the images in our training set. We will make sure that we indicate the batch size, the path to the directory of the training images, the target size for the images, and shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size, directory=train_dir , shuffle=True, target_size=(IMG_SHAPE,IMG_SHAPE))
# Out:
# Found 2935 images belonging to 5 classes.

# %% [markdown]
# Let's take 1 sample image from our training examples and repeat it 5 times so that the augmentation can be applied to the same image 5 times over randomly, to see the augmentation in action.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Apply Random Zoom
#
# In the cell below, we use ImageDataGenerator to create a transformation that rescales the images by 255 and then applies a random zoom of up to 50%. Then we use the `.flow_from_directory` method to apply the above transformation to the images in our training set. We will make sure that we indicate the batch size, the path to the directory of the training images, the target size for the images, and shuffle the images.

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size, directory=train_dir, shuffle=True, target_size=(IMG_SHAPE, IMG_SHAPE) )
# Out:
# Found 2935 images belonging to 5 classes.

# %% [markdown]
# Let's take 1 sample image from our training examples and repeat it 5 times so that the augmentation can be applied to the same image 5 times over randomly, to see the augmentation in action.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ### Put It All Together
#
# In the cell below, we will use ImageDataGenerator to create a transformation that rescales the images by 255 and that applies:
#
# - random 45 degree rotation
# - random zoom of up to 50%
# - random horizontal flip
# - width shift of 0.15
# - height shift of 0.15
#
# Then we will use the `.flow_from_directory` method to apply the above transformation to the images in our training set. We will make sure to indicate the batch size, the path to the directory of the training images, the target size for the images, to shuffle the images, and to set the class mode to `sparse`.

# %%
image_gen_train = ImageDataGenerator(rescale=1./255, rotation_range = 45, zoom_range = 50, horizontal_flip=True, height_shift_range = 0.15, width_shift_range = 0.15)


train_data_gen = image_gen_train.flow_from_directory(batch_size=batch_size, directory = train_dir, shuffle=True, target_size=(IMG_SHAPE, IMG_SHAPE), class_mode='sparse')

# %% [markdown]
# Let's visualize how a single image would look like 5 different times, when we pass these augmentations randomly to our dataset.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %% [markdown]
# ###  Create a Data Generator for the Validation Set
#
# Generally, we only apply data augmentation to our training examples. So, in the cell below, we use ImageDataGenerator to create a transformation that only rescales the images by 255. Then we use the `.flow_from_directory` method to apply the above transformation to the images in our validation set. Make sure that we indicate the batch size, the path to the directory of the validation images, the target size for the images, and to set the class mode to `sparse`. Remember that it is not necessary to shuffle the images in the validation set.

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)
val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size, directory = val_dir, target_size=(IMG_SHAPE, IMG_SHAPE),class_mode='sparse' )
# Out:
# Found 735 images belonging to 5 classes.

# %% [markdown]
# # Create the CNN
#
# In the cell below, we will create a convolutional neural network that consists of 3 convolution blocks. Each convolutional block contains a `Conv2D` layer followed by a max pool layer. The first convolutional block should have 16 filters, the second one should have 32 filters, and the third one should have 64 filters. All convolutional filters should be 3 x 3. All max pool layers should have a `pool_size` of `(2, 2)`.
#
# After the 3 convolutional blocks we should have a flatten layer followed by a fully connected layer with 512 units. The CNN should output class probabilities based on 5 classes which is done by the **softmax** activation function. All other layers should use a **relu** activation function. We should also add Dropout layers with a probability of 20%, where appropriate.

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %% [markdown]
# # Compile the Model
#
# In the cell below, we will compile our model using the ADAM optimizer, the sparse cross entropy function as a loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so make sure you also pass the metrics argument.

# %%
# Compile the model
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %% [markdown]
# # Train the Model
#
# In the cell below, we will train our model using the **fit_generator** function instead of the usual **fit** function. We have to use the `fit_generator` function because we are using the **ImageDataGenerator** class to generate batches of training and validation data for our model. We will train the model for 80 epochs and make sure that we use the proper parameters in the `fit_generator` function.

# %%
epochs = 80

history = model.fit(
    train_data_gen,
    steps_per_epoch = int(np.ceil(num_train_examples / float(batch_size))),
    epochs= epochs,
    validation_data = val_data_gen,
    validation_steps= int(np.ceil(num_val_examples / float(batch_size)))
)
# Out:
# Epoch 1/80
# 30/30 [==============================] - 30s 858ms/step - loss: 1.6488 - accuracy: 0.2549 - val_loss: 1.3698 - val_accuracy: 0.4218
# Epoch 2/80
# 30/30 [==============================] - 26s 884ms/step - loss: 1.4793 - accuracy: 0.3554 - val_loss: 1.5543 - val_accuracy: 0.3769
# Epoch 3/80
# 30/30 [==============================] - 26s 868ms/step - loss: 1.4306 - accuracy: 0.3782 - val_loss: 1.6436 - val_accuracy: 0.3673
# Epoch 4/80
# 30/30 [==============================] - 26s 867ms/step - loss: 1.3834 - accuracy: 0.4034 - val_loss: 1.6062 - val_accuracy: 0.4000
# Epoch 5/80
# 30/30 [==============================] - 26s 879ms/step - loss: 1.3516 - accuracy: 0.4467 - val_loss: 1.4764 - val_accuracy: 0.4463
# Epoch 6/80
# 30/30 [==============================] - 26s 884ms/step - loss: 1.3184 - accuracy: 0.4586 - val_loss: 1.3362 - val_accuracy: 0.4490
# Epoch 7/80
# 30/30 [==============================] - 27s 920ms/step - loss: 1.2820 - accuracy: 0.4729 - val_loss: 1.3529 - val_accuracy: 0.4340
# Epoch 8/80
# 30/30 [==============================] - 26s 875ms/step - loss: 1.2643 - accuracy: 0.4794 - val_loss: 1.3759 - val_accuracy: 0.4639
# Epoch 9/80
# 30/30 [==============================] - 26s 874ms/step - loss: 1.2011 - accuracy: 0.5155 - val_loss: 1.3492 - val_accuracy: 0.4830
# Epoch 10/80
# 30/30 [==============================] - 26s 864ms/step - loss: 1.1773 - accuracy: 0.5135 - val_loss: 1.4329 - val_accuracy: 0.3986
# Epoch 11/80
# 30/30 [==============================] - 26s 872ms/step - loss: 1.1529 - accuracy: 0.5261 - val_loss: 1.2048 - val_accuracy: 0.5075
# Epoch 12/80
# 30/30 [==============================] - 26s 868ms/step - loss: 1.1460 - accuracy: 0.5298 - val_loss: 1.2115 - val_accuracy: 0.5374
# Epoch 13/80
# 30/30 [==============================] - 27s 875ms/step - loss: 1.1163 - accuracy: 0.5339 - val_loss: 1.3101 - val_accuracy: 0.4639
# Epoch 14/80
# 30/30 [==============================] - 26s 886ms/step - loss: 1.1185 - accuracy: 0.5506 - val_loss: 1.3539 - val_accuracy: 0.4204
# Epoch 15/80
# 30/30 [==============================] - 26s 873ms/step - loss: 1.0904 - accuracy: 0.5659 - val_loss: 1.3259 - val_accuracy: 0.4898
# Epoch 16/80
# 30/30 [==============================] - 26s 873ms/step - loss: 1.0945 - accuracy: 0.5503 - val_loss: 1.2027 - val_accuracy: 0.5388
# Epoch 17/80
# 30/30 [==============================] - 26s 874ms/step - loss: 1.0658 - accuracy: 0.5649 - val_loss: 1.1760 - val_accuracy: 0.5061
# Epoch 18/80
# 30/30 [==============================] - 26s 880ms/step - loss: 1.0728 - accuracy: 0.5693 - val_loss: 1.2538 - val_accuracy: 0.4993
# Epoch 19/80
# 30/30 [==============================] - 26s 842ms/step - loss: 1.0662 - accuracy: 0.5700 - val_loss: 1.4056 - val_accuracy: 0.4612
# Epoch 20/80
# 30/30 [==============================] - 26s 860ms/step - loss: 1.0554 - accuracy: 0.5727 - val_loss: 1.2594 - val_accuracy: 0.4599
# Epoch 21/80
# 30/30 [==============================] - 26s 854ms/step - loss: 1.0437 - accuracy: 0.5806 - val_loss: 1.4129 - val_accuracy: 0.4163
# Epoch 22/80
# 30/30 [==============================] - 28s 937ms/step - loss: 1.0600 - accuracy: 0.5697 - val_loss: 1.2906 - val_accuracy: 0.4762
# Epoch 23/80
# 30/30 [==============================] - 26s 870ms/step - loss: 1.0476 - accuracy: 0.5833 - val_loss: 1.2417 - val_accuracy: 0.4871
# Epoch 24/80
# 30/30 [==============================] - 26s 876ms/step - loss: 1.0137 - accuracy: 0.5997 - val_loss: 1.1282 - val_accuracy: 0.5442
# Epoch 25/80
# 30/30 [==============================] - 26s 871ms/step - loss: 1.0138 - accuracy: 0.5894 - val_loss: 1.2222 - val_accuracy: 0.4721
# Epoch 26/80
# 30/30 [==============================] - 26s 877ms/step - loss: 1.0119 - accuracy: 0.5966 - val_loss: 1.1156 - val_accuracy: 0.5592
# Epoch 27/80
# 30/30 [==============================] - 26s 865ms/step - loss: 1.0044 - accuracy: 0.5993 - val_loss: 1.2275 - val_accuracy: 0.4939
# Epoch 28/80
# 30/30 [==============================] - 26s 840ms/step - loss: 1.0011 - accuracy: 0.5969 - val_loss: 1.2002 - val_accuracy: 0.5102
# Epoch 29/80
# 30/30 [==============================] - 26s 848ms/step - loss: 1.0088 - accuracy: 0.5945 - val_loss: 1.1911 - val_accuracy: 0.5197
# Epoch 30/80
# 30/30 [==============================] - 26s 874ms/step - loss: 0.9861 - accuracy: 0.6068 - val_loss: 1.2039 - val_accuracy: 0.5224
# Epoch 31/80
# 30/30 [==============================] - 26s 877ms/step - loss: 0.9792 - accuracy: 0.6123 - val_loss: 1.1413 - val_accuracy: 0.5578
# Epoch 32/80
# 30/30 [==============================] - 26s 872ms/step - loss: 0.9813 - accuracy: 0.6068 - val_loss: 1.1001 - val_accuracy: 0.5592
# Epoch 33/80
# 30/30 [==============================] - 27s 887ms/step - loss: 0.9621 - accuracy: 0.6147 - val_loss: 1.1421 - val_accuracy: 0.5633
# Epoch 34/80
# 30/30 [==============================] - 26s 868ms/step - loss: 0.9801 - accuracy: 0.6133 - val_loss: 1.2906 - val_accuracy: 0.5048
# Epoch 35/80
# 30/30 [==============================] - 26s 874ms/step - loss: 0.9829 - accuracy: 0.6085 - val_loss: 1.1379 - val_accuracy: 0.5388
# Epoch 36/80
# 30/30 [==============================] - 26s 873ms/step - loss: 0.9803 - accuracy: 0.6055 - val_loss: 1.1711 - val_accuracy: 0.5524
# Epoch 37/80
# 30/30 [==============================] - 34s 1s/step - loss: 0.9659 - accuracy: 0.6157 - val_loss: 1.1591 - val_accuracy: 0.5442
# Epoch 38/80
# 30/30 [==============================] - 35s 1s/step - loss: 0.9433 - accuracy: 0.6273 - val_loss: 1.1189 - val_accuracy: 0.5701
# Epoch 39/80
# 30/30 [==============================] - 39s 1s/step - loss: 0.9336 - accuracy: 0.6266 - val_loss: 1.1517 - val_accuracy: 0.5687
# Epoch 40/80
# 30/30 [==============================] - 39s 1s/step - loss: 0.9503 - accuracy: 0.6191 - val_loss: 1.1326 - val_accuracy: 0.5633
# Epoch 41/80
# 30/30 [==============================] - 39s 1s/step - loss: 0.9438 - accuracy: 0.6201 - val_loss: 1.1702 - val_accuracy: 0.5537
# Epoch 42/80
# 30/30 [==============================] - 35s 1s/step - loss: 0.9311 - accuracy: 0.6259 - val_loss: 1.1196 - val_accuracy: 0.5415
# Epoch 43/80
# 30/30 [==============================] - 38s 1s/step - loss: 0.9659 - accuracy: 0.6123 - val_loss: 1.1637 - val_accuracy: 0.5551
# Epoch 44/80
# 30/30 [==============================] - 34s 1s/step - loss: 0.9327 - accuracy: 0.6283 - val_loss: 1.1708 - val_accuracy: 0.5347
# Epoch 45/80
# 30/30 [==============================] - 26s 875ms/step - loss: 0.9300 - accuracy: 0.6242 - val_loss: 1.0652 - val_accuracy: 0.5728
# Epoch 46/80
# 30/30 [==============================] - 26s 882ms/step - loss: 0.9229 - accuracy: 0.6412 - val_loss: 1.1372 - val_accuracy: 0.5660
# Epoch 47/80
# 30/30 [==============================] - 27s 895ms/step - loss: 0.9378 - accuracy: 0.6296 - val_loss: 1.1450 - val_accuracy: 0.5701
# Epoch 48/80
# 30/30 [==============================] - 26s 868ms/step - loss: 0.9258 - accuracy: 0.6358 - val_loss: 1.0703 - val_accuracy: 0.5673
# Epoch 49/80
# 30/30 [==============================] - 26s 879ms/step - loss: 0.9243 - accuracy: 0.6341 - val_loss: 1.2245 - val_accuracy: 0.5578
# Epoch 50/80
# 30/30 [==============================] - 28s 925ms/step - loss: 0.9138 - accuracy: 0.6371 - val_loss: 1.1188 - val_accuracy: 0.5660
# Epoch 51/80
# 30/30 [==============================] - 26s 876ms/step - loss: 0.9110 - accuracy: 0.6412 - val_loss: 1.1075 - val_accuracy: 0.5741
# Epoch 52/80
# 30/30 [==============================] - 26s 868ms/step - loss: 0.8992 - accuracy: 0.6535 - val_loss: 1.1021 - val_accuracy: 0.5878
# Epoch 53/80
# 30/30 [==============================] - 26s 879ms/step - loss: 0.9100 - accuracy: 0.6371 - val_loss: 1.1537 - val_accuracy: 0.5810
# Epoch 54/80
# 30/30 [==============================] - 26s 868ms/step - loss: 0.9217 - accuracy: 0.6375 - val_loss: 1.2225 - val_accuracy: 0.5374
# Epoch 55/80
# 30/30 [==============================] - 27s 886ms/step - loss: 0.9183 - accuracy: 0.6354 - val_loss: 1.0447 - val_accuracy: 0.6054
# Epoch 56/80
# 30/30 [==============================] - 26s 877ms/step - loss: 0.8953 - accuracy: 0.6429 - val_loss: 1.1049 - val_accuracy: 0.5741
# Epoch 57/80
# 30/30 [==============================] - 26s 885ms/step - loss: 0.9000 - accuracy: 0.6392 - val_loss: 1.0706 - val_accuracy: 0.5673
# Epoch 58/80
# 30/30 [==============================] - 26s 868ms/step - loss: 0.8815 - accuracy: 0.6545 - val_loss: 1.1250 - val_accuracy: 0.5701
# Epoch 59/80
# 30/30 [==============================] - 26s 858ms/step - loss: 0.8768 - accuracy: 0.6497 - val_loss: 1.1352 - val_accuracy: 0.5442
# Epoch 60/80
# 30/30 [==============================] - 26s 854ms/step - loss: 0.8781 - accuracy: 0.6521 - val_loss: 1.2313 - val_accuracy: 0.5361
# Epoch 61/80
# 30/30 [==============================] - 26s 865ms/step - loss: 0.8839 - accuracy: 0.6613 - val_loss: 1.1015 - val_accuracy: 0.5497
# Epoch 62/80
# 30/30 [==============================] - 26s 874ms/step - loss: 0.8784 - accuracy: 0.6583 - val_loss: 1.0716 - val_accuracy: 0.5850
# Epoch 63/80
# 30/30 [==============================] - 26s 874ms/step - loss: 0.8889 - accuracy: 0.6433 - val_loss: 1.1233 - val_accuracy: 0.5864
# Epoch 64/80
# 30/30 [==============================] - 26s 880ms/step - loss: 0.8926 - accuracy: 0.6422 - val_loss: 1.1226 - val_accuracy: 0.5578
# Epoch 65/80
# 30/30 [==============================] - 28s 931ms/step - loss: 0.8810 - accuracy: 0.6511 - val_loss: 1.2731 - val_accuracy: 0.5415
# Epoch 66/80
# 30/30 [==============================] - 26s 883ms/step - loss: 0.8829 - accuracy: 0.6477 - val_loss: 1.1326 - val_accuracy: 0.5769
# Epoch 67/80
# 30/30 [==============================] - 27s 888ms/step - loss: 0.8422 - accuracy: 0.6705 - val_loss: 1.1154 - val_accuracy: 0.5769
# Epoch 68/80
# 30/30 [==============================] - 26s 877ms/step - loss: 0.8635 - accuracy: 0.6664 - val_loss: 1.1827 - val_accuracy: 0.5755
# Epoch 69/80
# 30/30 [==============================] - 26s 871ms/step - loss: 0.8570 - accuracy: 0.6583 - val_loss: 1.1545 - val_accuracy: 0.5646
# Epoch 70/80
# 30/30 [==============================] - 26s 884ms/step - loss: 0.8424 - accuracy: 0.6712 - val_loss: 1.1663 - val_accuracy: 0.5347
# Epoch 71/80
# 30/30 [==============================] - 27s 887ms/step - loss: 0.8652 - accuracy: 0.6596 - val_loss: 1.1241 - val_accuracy: 0.5850
# Epoch 72/80
# 30/30 [==============================] - 25s 839ms/step - loss: 0.8580 - accuracy: 0.6596 - val_loss: 1.1665 - val_accuracy: 0.5524
# Epoch 73/80
# 30/30 [==============================] - 27s 865ms/step - loss: 0.8646 - accuracy: 0.6630 - val_loss: 1.0730 - val_accuracy: 0.6054
# Epoch 74/80
# 30/30 [==============================] - 26s 860ms/step - loss: 0.8666 - accuracy: 0.6651 - val_loss: 1.0930 - val_accuracy: 0.6054
# Epoch 75/80
# 30/30 [==============================] - 26s 873ms/step - loss: 0.8287 - accuracy: 0.6773 - val_loss: 1.1534 - val_accuracy: 0.5878
# Epoch 76/80
# 30/30 [==============================] - 26s 860ms/step - loss: 0.8717 - accuracy: 0.6630 - val_loss: 1.1335 - val_accuracy: 0.5810
# Epoch 77/80
# 30/30 [==============================] - 27s 892ms/step - loss: 0.8410 - accuracy: 0.6637 - val_loss: 1.1274 - val_accuracy: 0.5741
# Epoch 78/80
# 30/30 [==============================] - 26s 871ms/step - loss: 0.8392 - accuracy: 0.6630 - val_loss: 1.2245 - val_accuracy: 0.5714
# Epoch 79/80
# 30/30 [==============================] - 26s 873ms/step - loss: 0.8260 - accuracy: 0.6750 - val_loss: 1.1530 - val_accuracy: 0.5755
# Epoch 80/80
# 30/30 [==============================] - 26s 883ms/step - loss: 0.8316 - accuracy: 0.6756 - val_loss: 1.2514 - val_accuracy: 0.5524

# %% [markdown]
# # Plot Training and Validation Graphs.
#
# In the cell below, we will plot the training and validation accuracy/loss graphs.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()

# %% [markdown]
# # TODO: Experiment with Different Parameters
#
# So far you've created a CNN with 3 convolutional layers and followed by a fully connected layer with 512 units. In the cells below create a new CNN with a different architecture. Feel free to experiment by changing as many parameters as you like. For example, you can add more convolutional layers, or more fully connected layers. You can also experiment with different filter sizes in your convolutional layers, different number of units in your fully connected layers, different dropout rates, etc... You can also experiment by performing image augmentation with more image transformations that we have seen so far. Take a look at the [ImageDataGenerator Documentation](https://keras.io/preprocessing/image/) to see a full list of all the available image transformations. For example, you can add shear transformations, or you can vary the brightness of the images, etc... Experiment as much as you can and compare the accuracy of your various models. Which parameters give you the best result?
